# %%
import pandas as pd
import re
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
import torch

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
url = "https://storage.googleapis.com/adsp-nlp-open/data/nlp_a_6_news.json"
news_df = pd.read_json(url, orient="records", lines=True).sample(n=5000, random_state=123)
news_df.head()
# Out:
#                                                     url       date language  \
# 3539  https://www.seattletimes.com/nation-world/fath... 2022-03-04       en
# 1151  http://oaklandnewsnow.com/bright-spot-free-yog... 2022-02-24       en
# 2789  https://finance.yahoo.com/news/liquid-media-pr... 2022-06-04       en
# 6205  https://www.benzinga.com/m-a/22/01/25220259/ko... 2022-01-25       en
# 1367  https://federalnewsnetwork.com/u-s-news/2022/0... 2022-01-21       en
#
#                                                   title  \
# 3539  Father mourns son after shelling on Ukraine so...
# 1151  Bright Spot: Free yoga classes for veterans | ...
# 2789             Liquid Media Provides Corporate Update
# 6205  Kornit Digital Ltd. (NYSE:KRNT) - Kornit Digit...
# 1367  Prosecutor: Alex Murdaugh now faces 75 charges...
#
#                                                    text
# 3539  Father mourns son after shelling on Ukraine so...
# 1151  Bright Spot: Free yoga classes for veterans | ...
# 2789  Liquid Media Provides Corporate Update        ...
# 6205   Kornit Digital Ltd. (NYSE:KRNT) - Kornit Digi...
# 1367   Prosecutor: Alex Murdaugh now faces 75 charge...

# %%
pd.set_option('display.max_colwidth', None)
news_df["text"].iloc[0]
# Out:
# 'Father mourns son after shelling on Ukraine soccer field | The Seattle Times  Skip to contentCoronavirusLocal NewsTraffic LabLaw & JusticeLocal PoliticsEducationEducation LabEastsideEnvironmentHealthDataMental HealthProject HomelessTimes WatchdogBusiness & TechBoeing & AerospaceAmazonMicrosoftTechnologyReal EstateEconomyArtificial IntelligenceNation & WorldNation & World PoliticsOdditiesSportsSeahawksHuskiesCougarsMarinersSoundersStormKrakenHigh School SportsOn TV/RadioEntertainmentMoviesBooksMusicTheaterClassical MusicTV/StreamingComicsGames & PuzzlesHoroscopesLifeFood & DrinkTravel & OutdoorsWellnessPetsRant & RavePacific NW MagazineHomes & Real EstateOpinionEditorialsLetters to the EditorDavid HorseyFree PressVideoPhotographyObituariesNews ObituariesPaid ObituariesNewslettersPrint ReplicaToday’s PaperInside The TimesExploreJobsAutosNewslettersLog InSubscribeNation & WorldCoronavirusLocalBizSportsEntertainmentLifeHomesOpinion|JobsShopExploreNationWorldNation & World PoliticsOdditiesAll SectionsLocalCoronavirusTraffic LabProject HomelessLaw & JusticeLocal PoliticsEducationEducation LabEastsideEnvironmentNorthwestDataHealthTimes WatchdogMental HealthInside The TimesNews ObituariesPhoto & VideoNation & WorldPoliticsOdditiesBusinessBoeingAmazonArtificial IntelligenceMicrosoftTechnologyEconomyReal EstateSportsSeahawksHuskiesCougarsKrakenHigh SchoolsMarinersSoundersSnow SportsGeoff BakerMatt CalkinsLarry StoneBob CondottaOn TV/RadioEntertainmentMoviesBooksMusicTheaterClassical MusicTV/StreamingComicsGames & PuzzlesHoroscopesLifePacific NW MagazineFood & DrinkHappy HourWellnessHome & DecorPetsRant & RaveBethany Jean ClementTravelOutdoorsNorthwest HikesWashingtonOregonB.C.HawaiiOpinionEditorialsLettersOp-EdsDavid HorseyKate RileyMark HigginsBrier DudleyJennifer HemmingsenDerrick NunnallyFree PressColumnistsFYI GuySeattle SketcherDanny WestneatNaomi IshisakaJon TaltonJobsAutosHomes ListingsClassifiedsPaid ObituariesExploreSponsored PostsSeattle Times StoreContactFAQsSubscriber ServicesPrint ReplicaToday’s PaperiOS AppAndroid App Nation & WorldNationWorldNation & World PoliticsOddities  Nation & WorldNewslettersLog InSubscribeNation & World     Father mourns son after shelling on Ukraine soccer field   March 3, 2022 at 5:07 pm  Updated March 3, 2022 at 7:03 pm    By MSTYSLAV CHERNOVThe Associated Press MARIUPOL, Ukraine (AP) — The surgeons leaving the operating room don’t make eye contact. One of them holds up his hands. Another looks down, defeated. It’s then that the father waiting at the doorway grabs his forehead, tears welling, and turns away, a wail about to escape his throat. The man, identified only as Serhii, enters the room and finds his 16-year-old son, Iliya, is still and draped by a blood-stained sheet. Serhii drops down, hugs Iliya’s lifeless head and convulses with grief. Iliya was fatally wounded Wednesday while playing soccer in Mariupol when shelling started amid the Russian invasion of Ukraine. The explosive hit the soccer field near a school in the Azov Sea city.Elsewhere in Mariupol, shelling illuminated darkening skies as medics stood in a parking lot, with heavy fighting continuing on the city outskirts on Thursday. The city was plunged into darkness as the battle knocked out most phone services and raised the prospect of food and water shortages.Without phone connections, medics did not know where to take the wounded. Others drove around the city, with one crew finding a wounded woman who was put on a stretcher, carried down the stairs and placed into an ambulance, her hands shaking rapidly. Advertising Cutting off Ukraine’s access to the Black and Azov Seas would deal a crippling blow to Ukraine’s economy. It would also allow Russia to build a land corridor to Crimea, which it seized in 2014.Russian President Vladimir Putin’s forces have brought their superior firepower to bear over the past few days, launching hundreds of missiles and artillery attacks on cities and other sites around the country and making  ...

# %%
def clean_news_article(text):
    if pd.isnull(text):
        return ""
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'(subscribe|sign in|home|events|advertise|contact|e-edition|privacy|terms of use|customer service|return to top|facebook|twitter|linkedin|email|more news|most popular|currently reading)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'(written by|view comments|submit an obituary|print archives|careers|about|©\d{4}.*?|all rights reserved)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'(read more|read the full story|read more on this story|read more about this topic|read more from this author|read more from this publication)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'(user|cookie|website|description available)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'(privacy policy|terms of service|advertising|contact us|about us|site map|accessibility)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'(jpg|video|resize|com|https|media|quality|link|new tab|tab|com|subscription)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'(td|margin|color|package|width|font|menu|linux|padding|max width|privacy policy|terms of service|advertising|about us|site map)', '', text, flags=re.IGNORECASE)
    text = re.sub(r'[•|→|«|»]', '', text)
    text = re.sub(r'\b[A-Z][a-z]{2,10}( [A-Z][a-z]{2,10}){1,4}\b(?=\s)', '', text)
    text = re.sub(r'\s{2,}', ' ', text)
    return text.strip()

# %%
news_df['cleaned_text'] = news_df['text'].apply(clean_news_article)

news_df["cleaned_text"].iloc[0]
# Out:
# 'Father mourns son after shelling on Ukraine soccer field to contentCoronavirusTraffic LabLaw & JusticeLocal PoliticsEducationEducation LabEastsideEnvironmentHealthDataMental HealthProject lessTimes WatchdogBusiness & TechBoeing & AerospaceAmazonMicrosoftTechnologyEconomyArtificial IntelligenceNation & WorldNation & World PoliticsOdditiesSeahawksHuskiesCougarsMarinersSoundersStormKrakenHigh School On TV/RadioEntertainmentMoviesBooksMusicTheaterClassical MusicTV/StreamingComicsGames & PuzzlesHoroscopesLifeFood & DrinkTravel & OuoorsWellnessPetsRant & RavePacific NW Magazines & EditorialsLetters to the EditorDavid HorseyFree PressVideoPhotography Paid sPrint ReplicaToday’s PaperInside The TimesExploreJobsAutossLog InNation & WorldCoronavirusLocalBizEntertainmentLifesJobsShopExploreNationWorldNation & World PoliticsOdditiesAll SectionsLocalCoronavirusTraffic LabProject lessLaw & JusticeLocal PoliticsEducationEducation LabEastsideEnvironmentNorthwesataHealthTimes WatchdogMental HealthInside & VideoNation & WorldPoliticsOdditiesBusinessBoeingAmazonArtificial IntelligenceMicrosoftTechnologyEconomySeahawksHuskiesCougarsKrakenHigh SchoolsMarinersSoundersSnow Geoff BakerMatt CalkinsLarry StoneBob CondottaOn TV/RadioEntertainmentMoviesBooksMusicTheaterClassical MusicTV/StreamingComicsGames & PuzzlesHoroscopesLifePacific NW MagazineFood & DrinkHappy HourWellness & DecorPetsRant & RaveBethany Jean ClementTravelOuoorsNorthwest HikesWashingtonOregonB.C.HawaiiEditorialsLettersOp-EdsDavid HorseyKate RileyMark HigginsBrier DudleyJennifer HemmingsenDerrick NunnallyFree PressColumnistsFYI GuySeattle SketcherDanny WestneatNaomi IshisakaJon TaltonJobsAutoss ListingsPaid ExploreSponsored PostsSeattle Times StoreFAQsr ServicesPrint ReplicaToday’s PaperiOS AppAndroid & WorldNationWorldNation & World PoliticsOddities Nation & WorldsLog InNation & mourns son after shelling on Ukraine soccer field March 3, 2022 at 5:07 pm 3, 2022 at 7:03 pm By MSTYSLAV CHERNOVThe MARIUPOL, Ukraine (AP) — The surgeons leaving the operating room don’t make eye . One of them holds up his hands. Another looks down, defeated. It’s then that the father waiting at the doorway grabs his forehead, tears welling, and turns away, a wail to escape his throat. The man, identified only as Serhii, enters the room and finds his 16-year-old son, Iliya, is still and draped by a blood-stained sheet. Serhii drops down, hugs Iliya’s lifeless head and convulses with grief. Iliya was fatally wounded Wednesday while playing soccer in Mariupol when shelling started amid the Russian invasion of Ukraine. The explosive hit the soccer field near a school in the city.Elsewhere in Mariupol, shelling illuminated darkening skies as medics stood in a parking lot, with heavy fighting continuing on the city outskirts on Thursday. The city was plunged into darkness as the battle knocked out most phone services and raised the prospect of food and water shortages.Without phone connections, medics did not know where to take the wounded. Others drove around the city, with one crew finding a wounded woman who was put on a stretcher, carried down the stairs and placed into an ambulance, her hands shaking rapidly. Cutting off Ukraine’s access to the Black and would deal a crippling blow to Ukraine’s economy. It would also allow Russia to build a land corridor to Crimea, which it seized in 2014. Putin’s forces have brought their superior firepower to bear over the past few days, launching hundreds of missiles and artillery attacks on cities and other sites around the country and making significant gains in the south. announced the capture of the southern city of Kherson, a vital port of 280,000, and local Ukrainian officials confirmed the takeover of the government headquarters there, making it the first major city to fall since the invasion began a week ago. MSTYSLAV CHERNOV & World StoriesDon’t use these 3 unauthorized COVID tests, FDA warns. You might get a false result Should you still wear a mask after mandat ...

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
embedding_model = SentenceTransformer("thenlper/gte-small", device=device)
umap_model = UMAP(n_components=20, min_dist=0.0, metric='cosine', random_state=42)
hdbscan_model = HDBSCAN(min_cluster_size=50, metric='euclidean', cluster_selection_method='eom')
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 2))
ctfidf_model = ClassTfidfTransformer()

# %%
topic_model = BERTopic(
    embedding_model=embedding_model,
    umap_model=umap_model,
    hdbscan_model=hdbscan_model,
    vectorizer_model=vectorizer_model,
    ctfidf_model=ctfidf_model,
)

# %%
topics, probs = topic_model.fit_transform(news_df["cleaned_text"].tolist())

# %%
#topic_model.visualize_topics(topics=topics)

# %%
pd.reset_option('display.max_colwidth')
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1   1440                              -1_2022_video_com_jpg
# 1       0    482                             0_new_iphone_pro_apple
# 2       1    473                         1_shares_nasdaq_stock_nyse
# 3       2    349  2_said_musictv_musictv streamingcomicsgames_st...
# 4       3    343                               3_2022_pm_game_games
# 5       4    330                          4_data_cloud_security_new
# 6       5    259                   5_inflation_fed_canada_bloomberg
# 7       6    259             6_nbcchicago com_nbcchicago_jpg_resize
# 8       7    171                            7_india_2022_covid_said
# 9       8    163                    8_link opens_link_opens_new tab
# 10      9    146                       9_days_games_new_video games
# 11     10    119                           10_75pt_style_right_nbsp
# 12     11     83                   11_market_forecast_report_growth
# 13     12     78                        12_crypto_btc_traded_dollar
# 14     13     76                     13_ukraine_russia_russian_said
# 15     14     59                    14_symbols_add_currently_symbol
# 16     15     58        15_chapter_stories super_metaverse_leetcode
# 17     16     57                              16_types_type_npm_use
# 18     17     55                      17_pdf file_products_care_pdf
#
#                                        Representation  \
# 0   [2022, video, com, jpg, resize, 07, https, med...
# 1   [new, iphone, pro, apple, best, windows, 2022,...
# 2   [shares, nasdaq, stock, nyse, company, equitie...
# 3   [said, musictv, musictv streamingcomicsgames, ...
# 4   [2022, pm, game, games, new, pc, gaming, xbox,...
# 5   [data, cloud, security, new, prwire, 2022, bus...
# 6   [inflation, fed, canada, bloomberg, rates, mar...
# 7   [nbcchicago com, nbcchicago, jpg, resize, medi...
# 8   [india, 2022, covid, said, rs, live, delhi, ne...
# 9   [link opens, link, opens, new tab, tab, opens ...
# 10  [days, games, new, video games, hours, game, a...
# 11  [75pt, style, right, nbsp, right 75pt, 75pt ri...
# 12  [market, forecast, report, growth, global, 202...
# 13  [crypto, btc, traded, dollar, bitcoin, dollar ...
# 14  [ukraine, russia, russian, said, ukrainian, wa...
# 15  [symbols, add, currently, symbol, market, quot...
# 16  [chapter, stories super, metaverse, leetcode, ...
# 17  [types, type, npm, use, version, module, ts, t...
# 18  [pdf file, products, care, pdf, product, file,...
#
#                                   Representative_Docs
# 0   [2022 #NBAAllStar captured on film 🎞📸 Oakland ...
# 1   [sales vs Day: deals to buy now and what to wa...
# 2   [Inc. in Inc. (NYSE:HWM) - ETF to main content...
# 3   [Head of US has COVID-19 to contentCoronavirus...
# 4   [manages to get 30GB/$50 due to new UsSyrupCas...
# 5   [DocuSign 2023 Financial ResultsSkip to conten...
# 6   [On Crypto, - BNN BloombergAre you looking for...
# 7   [kept two foster dogs after crashing his plane...
# 8   [IAC aircraft warship carrier begins next of s...
# 9   [This Week's 10 PEOPLE.com Skip to content PEO...
# 10  [of Duty games be on One? - BreakLocalHeadline...
# 11  [Stock market live updates: January 25, 2022 M...
# 12  [by Size, Share, Growth, Application, Segmenta...
# 13  [Tycoon (TYC) Trading Up 2.3% - to main conten...
# 14  [Asian stocks plunge after Putin announces act...
# 15  [Approach 52- - to main contentMarket Activity...
# 16  [albertgstoehl HackerNoonStart WritingNotifica...
# 17  [@types/cote: Docs, Tutorials, Reviews Openbas...
# 18  [Visit the support page for your SEAL RING FOR...

# %%
pd.set_option('display.max_colwidth', None)

topic_info = topic_model.get_topic_info()
topic_info[["Topic", "Count", "Name", "Representation"]]
# Out:
#     Topic  Count  \
# 0      -1   1440
# 1       0    482
# 2       1    473
# 3       2    349
# 4       3    343
# 5       4    330
# 6       5    259
# 7       6    259
# 8       7    171
# 9       8    163
# 10      9    146
# 11     10    119
# 12     11     83
# 13     12     78
# 14     13     76
# 15     14     59
# 16     15     58
# 17     16     57
# 18     17     55
#
#                                                                 Name  \
# 0                                              -1_2022_video_com_jpg
# 1                                             0_new_iphone_pro_apple
# 2                                         1_shares_nasdaq_stock_nyse
# 3   2_said_musictv_musictv streamingcomicsgames_streamingcomicsgames
# 4                                               3_2022_pm_game_games
# 5                                          4_data_cloud_security_new
# 6                                   5_inflation_fed_canada_bloomberg
# 7                             6_nbcchicago com_nbcchicago_jpg_resize
# 8                                            7_india_2022_covid_said
# 9                                    8_link opens_link_opens_new tab
# 10                                      9_days_games_new_video games
# 11                                          10_75pt_style_right_nbsp
# 12                                  11_market_forecast_report_growth
# 13                                       12_crypto_btc_traded_dollar
# 14                                    13_ukraine_russia_russian_said
# 15                                   14_symbols_add_currently_symbol
# 16                       15_chapter_stories super_metaverse_leetcode
# 17                                             16_types_type_npm_use
# 18                                     17_pdf file_products_care_pdf
#
#                                                                                                                                                                                                                                                                                                                    Representation
# 0                                                                                                                                                                                                                                                             [2022, video, com, jpg, resize, 07, https, media, 2022 07, quality]
# 1                                                                                                                                                                                                                                                           [new, iphone, pro, apple, best, windows, 2022, tab, opens new, opens]
# 2                                                                                                                                                                                                                                                   [shares, nasdaq, stock, nyse, company, equities, quarter, rating, llc, price]
# 3   [said, musictv, musictv streamingcomicsgames, streamingcomicsgames, justicelocal, politicseducationeducation, radioentertainmentmoviesbooksmusictheaterclassical musictv, radioentertainmentmoviesbooksmusictheaterclassical, justicelocal politicseducationeducation, tv radioentertainmentmoviesbooksmusictheaterclassical]
# 4                                                                                                                                                                                                                                                                   [2022, pm, game, games, new, pc, gaming, xbox, microsoft, 11]
# 5                                                                                                                                                                                                                                               [data, cloud, security, new, prwire, 2022, business, customers, technology, gaap]
# 6                                                                                                                                                                                                                                               [inflation, fed, canada, bloomberg, rates, market, oil, daily chase, ceo, stocks]
# 7                                                                                                                                                                                                                                  [nbcchicago com, nbcchicago, jpg, resize, media nbcchicago, star, 2022, media, quality, https]
# 8                                                                                                                                                                                                                                                                       [india, 2022, covid, said, rs, live, delhi, new, 19, ipl]
# 9                                                                                                                                                                                                                                       [link opens, link, opens, new tab, tab, opens new, people, new, people com, subscription]
# 10                                                                                                                                                                                                                                                       [days, games, new, video games, hours, game, article, day, video, covid]
# 11                                                                                                                                                                                                                                [75pt, style, right, nbsp, right 75pt, 75pt right, left 75pt, 75pt left, serif, helvetica sans]
# 12                                                                                                                                                                                                                                                  [market, forecast, report, growth, global, 2022, analysis, 2028, share, 2017]
# 13                                                                                                                                                                                                                                      [crypto, btc, traded, dollar, bitcoin, dollar trades, trades, cryptocurrency, musk, 2022]
# 14                                                                                                                                                                                                                                            [ukraine, russia, russian, said, ukrainian, war, military, putin, invasion, attack]
# 15                                                                                                                                                                                                                                          [symbols, add, currently, symbol, market, quotes, data, nasdaq, earnings, nasdaq com]
# 16                                                                                                                                                                                                               [chapter, stories super, metaverse, leetcode, chronological order, chronological, super, super 1931, 1931, java]
# 17                                                                                                                                                                                                                                                         [types, type, npm, use, version, module, ts, typescript, json, ubuntu]
# 18                                                                                                                                                                                                                                            [pdf file, products, care, pdf, product, file, mb, manual pdf, accessories, manual]
